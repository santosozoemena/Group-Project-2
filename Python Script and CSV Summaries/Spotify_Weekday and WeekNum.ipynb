# %%
# Dependencies
import csv
import pandas as pd
import os
import numpy as np
from datetime import datetime

# %%
# Read csv
csvpath = os.path.join('Desktop', 'Project-2', 'spotify_data.csv')
import csv

spotify_df = pd.read_csv(csvpath, encoding="ISO-8859-1")

# %%
# Add a normalizing column for each song in each region to convert to streams per million of populace
spotify_df["Streams per 1 million"] = (spotify_df["Streams"]/spotify_df["Population"]*1000000).round(2)

# %%
# Drop the obsolete "Stream % of Pop" column
del spotify_df['Stream % of Pop']

# %%
# Add a blank column to flag number one hits
spotify_df['Number One']=np.nan

# %%
# Make sure dates are formatted as such
spotify_df['Date'] = pd.to_datetime(spotify_df['Date'])
spotify_df['RELEASE'] = pd.to_datetime(spotify_df['RELEASE'])

# %%
# Add weekday and weeknumber columns
spotify_df["Weekday"] = spotify_df["Date"].dt.weekday_name
spotify_df["Weeknumber"] = spotify_df["Date"].dt.week

# %%
spotify_df.head()
# Out:
#         Date  Position  Streams                  Track Name         Artist  \
# 0 2017-01-01         1    19272  Reggaetn Lento (Bailemos)           CNCO
# 1 2017-01-01         2    19270                    Chantaje        Shakira
# 2 2017-01-01         3    15761   Otra Vez (feat. J Balvin)  Zion & Lennox
# 3 2017-01-01         4    14954                Vente Pa' Ca   Ricky Martin
# 4 2017-01-01         5    14269                      Safari       J Balvin
#
#     Region                                                URL    RELEASE  BPM  \
# 0  Ecuador  https://open.spotify.com/track/3AEZUABDXNtecAO... 2016-08-26   94
# 1  Ecuador  https://open.spotify.com/track/6mICuAdrwEjh6Y6... 2017-05-26  102
# 2  Ecuador  https://open.spotify.com/track/3QwBODjSEzelZyV... 2016-09-30   96
# 3  Ecuador  https://open.spotify.com/track/7DM4BPaS7uofFul... 2016-09-23  100
# 4  Ecuador  https://open.spotify.com/track/6rQSrBHf7HlZjtc... 2016-06-24  180
#
#    ENERGY     ...      VALENCE    LENGTH  ACOUSTIC  POP.  Population  \
# 0      84     ...           71  0.154861        40    81    16290913
# 1      77     ...           91  0.136111        19    83    16290913
# 2      77     ...           70  0.145139         6    81    16290913
# 3      92     ...           53  0.179861         0    80    16290913
# 4      69     ...           63  0.143056        53    73    16290913
#
#    Country Primary Language  Streams per 1 million Number One  Weekday  \
# 0                   Spanish                1182.99        NaN   Sunday
# 1                   Spanish                1182.87        NaN   Sunday
# 2                   Spanish                 967.47        NaN   Sunday
# 3                   Spanish                 917.94        NaN   Sunday
# 4                   Spanish                 875.89        NaN   Sunday
#
#    Weeknumber
# 0          52
# 1          52
# 2          52
# 3          52
# 4          52
#
# [5 rows x 22 columns]

# %%
# Create a new dataframe that eliminates Chile, Estonia, and Latvia (because we are missing dates for their data)
spotify_reduced_df = spotify_df[~spotify_df['Region'].isin(['Chile', 'Estonia', 'Latvia'])]

# %%
spotify_sorted_df = spotify_reduced_df.sort_values(by=['Date', 'Region', 'Position'])

# %%
spotify_week_day_df = spotify_sorted_df.reset_index(drop=True)

# %%
# Remove dates that give us a rollover of week numbers
# spotify_week_day_df.loc[datetime.date(year=2017,month=1,day=2):datetime.date(year=2017,month=12,day=31)]

# %%
spotify_week_day_df.head()
# Out:
#         Date  Position  Streams                  Track Name        Artist  \
# 0 2017-01-01         1   253019                    Chantaje       Shakira
# 1 2017-01-01         2   223988                Vente Pa' Ca  Ricky Martin
# 2 2017-01-01         3   210943  Reggaetn Lento (Bailemos)          CNCO
# 3 2017-01-01         4   173865                      Safari      J Balvin
# 4 2017-01-01         5   153956                 Shaky Shaky  Daddy Yankee
#
#       Region                                                URL    RELEASE  \
# 0  Argentina  https://open.spotify.com/track/6mICuAdrwEjh6Y6... 2017-05-26
# 1  Argentina  https://open.spotify.com/track/7DM4BPaS7uofFul... 2016-09-23
# 2  Argentina  https://open.spotify.com/track/3AEZUABDXNtecAO... 2016-08-26
# 3  Argentina  https://open.spotify.com/track/6rQSrBHf7HlZjtc... 2016-06-24
# 4  Argentina  https://open.spotify.com/track/58IL315gMSTD37D... 2016-04-08
#
#    BPM  ENERGY     ...      VALENCE    LENGTH  ACOUSTIC  POP.  Population  \
# 0  102      77     ...           91  0.136111        19    83    44293293
# 1  100      92     ...           53  0.179861         0    80    44293293
# 2   94      84     ...           71  0.154861        40    81    44293293
# 3  180      69     ...           63  0.143056        53    73    44293293
# 4   88      63     ...           86  0.162500         6    68    44293293
#
#    Country Primary Language  Streams per 1 million Number One  Weekday  \
# 0                   Spanish                5712.35        NaN   Sunday
# 1                   Spanish                5056.93        NaN   Sunday
# 2                   Spanish                4762.41        NaN   Sunday
# 3                   Spanish                3925.31        NaN   Sunday
# 4                   Spanish                3475.83        NaN   Sunday
#
#    Weeknumber
# 0          52
# 1          52
# 2          52
# 3          52
# 4          52
#
# [5 rows x 22 columns]

# %%
spotify_by_day_df = spotify_week_day_df.groupby(["Date", "Weekday", "Weeknumber"]).agg({'Streams': ['sum'],
                                                                                      'Streams per 1 million': [sum]})
spotify_by_day_df = spotify_by_day_df.reset_index()

# %%
# SAVE A CSV OF THE TABLE ("spotify_week_day.csv")
spotify_by_day_df.to_csv("Desktop/Project-2/spotify_summary.csv", index=False, header=True)
